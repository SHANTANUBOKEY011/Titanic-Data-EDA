# %% [markdown]
# <a href="https://colab.research.google.com/github/SHANTANUBOKEY011/Titanic-Data-EDA/blob/main/Titanic_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Titanic Dataset Analysis :

# %% [markdown]
# ## Student name : Shantanu Nilkanth Bokey

# %% [markdown]
# ##Summary :
#
# Titanic, British luxury passenger liner that sank on April 15, 1912, en route to New York from Southampton, England, on its maiden voyage.
#
# The largest and most luxurious ship afloat, the Titanic had a double-bottomed hull divided into 16 watertight compartments. Because four of these could be flooded without endangering its buoyancy, it was considered unsinkable. Shortly before midnight on April 14, it collided with an iceberg southeast of Cape Race, Newfoundland; five compartments ruptured and the ship sank. Some 1,500 of its 2,200 passengers died.

# %% [markdown]
# ![Titanic.PNG](data:image/png;base64,...)

# %% [markdown]
# ##Objective :
# To analyse how many people survived , and died on basis of different class , fare , gender , age etc , and drawing conclusions on the given dataset, creating new columns as well for more clear understanding

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/titanic_train.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## Columns Description :
#
#
# *   PassengerId	:  Id of the Passengers who travelled.
#
# *   Survived    :  0 represent passenger died , 1 passenger survived.
#
# *   Pclass      : Passenger Class ( 1,2 and 3 ).
#
# *   Name        : Passenger name, along with their Titles and Surname at the beginning.
#
# *   Sex         : Gender of the passengers
#
# *   Age         : Age of the passengers.
#
# *   Sibsp       : Sibling,spouse
#
# *   Parch       : Parent ,childerns
#
# *   Ticket      : Ticket number
#
# *   Fare        : Ticket Price
#
# *   Cabin       : Cabin number
#
# *   Embarked    : Station letter ( S,C,Q )

# %% [markdown]
# ##Data overview :

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
sns.set_style('whitegrid')
sns.countplot(x='Survived',data=df)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.set_style('whitegrid')
sns.countplot(x='Survived',data= df)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %% [markdown]
# ### Column Types
#
# - **Numerical** - Age,Fare,PassengerId
# - **Categorical** - Survived, Pclass, Sex, SibSp, Parch,Embarked
# - **Mixed** - Name, Ticket, Cabin

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='summer')
# Out:
# <Axes: >

# %% [markdown]
# ##Conclusion
# * Roughly 20 percent of the Age data is missing. The
#   proportion of Age missing is likely small enough for reasonable replacement with some form of imputation. Looking at the Cabin column, it looks like we are just missing too much of that data to do something useful with at a basic level.

# %% [markdown]
# ## A) Univariate Analysis
#
# ---
#
#
#
# ---

# %% [markdown]
# ##Age column

# %%
df['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
sns.distplot(df['Age'].dropna(),kde=False,color='darkred',bins=40)

plt.show()
# Out:
# <ipython-input-69-99aa496998d1>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'].dropna(),kde=False,color='darkred',bins=40)

# %%
df['Age'].plot(kind='hist',bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Age'].plot(kind = 'kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Age'].plot(kind='box')
# Out:
# <Axes: >

# %%
df[df['Age'] > 65]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 33            34         0       2                 Wheadon, Mr. Edward H
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 672          673         0       2           Mitchell, Mr. Henry Michael
# 745          746         0       1          Crosby, Capt. Edward Gifford
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 33   male  66.0      0      0  C.A. 24579  10.5000   NaN        S
# 96   male  71.0      0      0    PC 17754  34.6542    A5        C
# 116  male  70.5      0      0      370369   7.7500   NaN        Q
# ...

# %%
df['Age'].isnull().sum()/len(df['Age'])*100
# Out:
# 19.865319865319865

# %% [markdown]
# ### Conclusion
#
#
# - Age is normally(almost) distributed
# - 20% of the values are missing
# - There are some outliers

# %% [markdown]
# ##Fare Column

# %%
df['Fare'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
df['Fare'].hist(color='green',bins=40,figsize=(8,4))
# Out:
# <Axes: >

# %%
df['Fare'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Fare'].skew()
# Out:
# 4.787316519674893

# %%
df['Fare'].plot(kind='box')
# Out:
# <Axes: >

# %%
df[df['Fare'] > 250]
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 27            28         0       1         Fortune, Mr. Charles Alexander
# 88            89         1       1             Fortune, Miss. Mabel Helen
# 258          259         1       1                       Ward, Miss. Anna
# 311          312         1       1             Ryerson, Miss. Emily Borie
# 341          342         1       1         Fortune, Miss. Alice Elizabeth
# 438          439         0       1                      Fortune, Mr. Mark
# 679          680         1       1     Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1                 Lesurer, Mr. Gustave J
# 742          743         1       1  Ryerson, Miss. Susan Parker "Suzette"
#
#         Sex   Age  SibSp  Parch    Ticket      Fare            Cabin Embarked
# 27     male  19.0      3      2     19950  263.0000      C23 C25 C27        S
# ...

# %% [markdown]
# ### Conclusion
#
#
#
# - The data is highly(positively) skewed
# - Fare col actually contains the group fare and not the individual fare(This migth be and issue)
# - We need to create a new col called individual fare

# %% [markdown]
# ##Categorical columns analysis :
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# ###Survived column

# %%
df['Survived'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: >

# %%
df['Survived'].value_counts().plot(kind = 'pie',autopct = '%.2f%%')
# Out:
# <Axes: ylabel='Survived'>

# %% [markdown]
# ###Conclusion
#
# *   61.62 % of passengers died
# *   38.38 % of passengers survived

# %% [markdown]
# ###Sex column

# %%
sns.set_style('whitegrid')
sns.countplot(data = df , x = 'Survived' , hue = 'Sex',palette='rainbow')
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
df['Sex'].value_counts().plot(kind = 'pie',autopct = "%0.2f%%",shadow = True)
# Out:
# <Axes: ylabel='Sex'>

# %% [markdown]
# ###Conclusion
#
#
#
# *   64.76% are male passenger
# *   35.24 % are female passenger

# %% [markdown]
# ##P class column

# %%
sns.set_style('whitegrid')
sns.countplot(x='Survived',hue='Pclass',data=df,palette='rainbow')
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
df['Pclass'].value_counts().plot(kind = 'pie',autopct = "%0.2f%%")
# Out:
# <Axes: ylabel='Pclass'>

# %% [markdown]
# ###Conclusion
#
#
# *   55.11 % passengers belong to class 3 , this indiacates that fare for this class are much cheaper as compared to class 1 and 2
# *   24.24 % passengers belong to class 1
# *   20.65 % passengers belong to class 2
# *   Fare price for class 1 and 2 are almost similar , due to which many passengers went for class 1 as compared to class 2

# %% [markdown]
# ###Sibsp column

# %%
df['SibSp'].value_counts()
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64

# %%
sns.countplot(x='SibSp',data=df)
# Out:
# <Axes: xlabel='SibSp', ylabel='count'>

# %%
df['SibSp'].value_counts().plot(kind = 'pie',autopct = "%02.f%%")
# Out:
# <Axes: ylabel='SibSp'>

# %% [markdown]
# ###Conclusions
#
# - Parch and SibSp cols can be merged to form  a new col call family_size
# - Create a new col called is_alone

# %% [markdown]
# # B) Bivariate Analysis
#
# ---
#
#
#
# ---

# %% [markdown]
# ##  Survival analysis in different Passenger class :

# %%
pd.crosstab(df['Survived'],df['Pclass'],normalize='columns')*100
# Out:
# Pclass            1          2          3
# Survived
# 0         37.037037  52.717391  75.763747
# 1         62.962963  47.282609  24.236253

# %%
sns.heatmap(pd.crosstab(df['Survived'],df['Pclass'],normalize='columns')*100)
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %%
pd.crosstab(df.Survived ,df.Pclass,normalize='columns')*100
# Out:
# Pclass            1          2          3
# Survived
# 0         37.037037  52.717391  75.763747
# 1         62.962963  47.282609  24.236253

# %% [markdown]
# ##Conclusion
#
# Survival percentage of people from different class :
# * Here we can see as we go from class 1 to class 3 people from higher class survived more as compared to people from lower class .
# * So here we can see that poor people , those who were in class 3 faced huge partiality , as compared to other class .

# %% [markdown]
# ##  Survival analysis on different genders :

# %%
pd.crosstab(df['Survived'],df['Sex'],normalize='columns')*100
# Out:
# Sex          female       male
# Survived
# 0         25.796178  81.109185
# 1         74.203822  18.890815

# %% [markdown]
# ##Conclusion
#
#
# ```
#  1) Female survival rate : 74.2  %
#  2) Male survival rate : 18.89   %
# ```
# * Here you can see there is a significant difference btwn survival rate of male and female , here female and mens were given more priority for survival

# %% [markdown]
# ## Survival analysis on basis of station :

# %%
pd.crosstab(df['Survived'],df['Embarked'],normalize='columns')*100
# Out:
# Embarked          C          Q          S
# Survived
# 0         44.642857  61.038961  66.304348
# 1         55.357143  38.961039  33.695652

# %% [markdown]
# ## Conclusion
# * Here we can those passengers who were from station C , survived more , which indicates that , people from C station might of higher class and status .

# %% [markdown]
# ## Passenger class analysis on different embarked stations :

# %%
pd.crosstab(df['Pclass'],df['Embarked'],normalize='columns')*100
# Out:
# Embarked          C          Q          S
# Pclass
# 1         50.595238   2.597403  19.720497
# 2         10.119048   3.896104  25.465839
# 3         39.285714  93.506494  54.813665

# %% [markdown]
# ## Conclusion
# * Here we can see the 50 % of the passengers from class 1 were from station c  .

# %% [markdown]
# ## Survival Kde plot for different ages :

# %%
df[df['Survived'] == 1]['Age'].plot(kind = 'kde', label = 'Survived')
df[df['Survived'] == 0]['Age'].plot(kind = 'kde', label = 'Not Survived')

plt.legend()
plt.show()

# %% [markdown]
# ##Conclusion
# From this kde plot we can draw some conclusions ,as mentioned below
#
#
# 1.   Here we can see for age 0-10/15 , 60-80 Survived more , this means childrens and old aged peoples were given more priority for survival.
# 2.   Here we can see that for age 20-60 , most of the people didnt survived.

# %% [markdown]
# ## Ticket analysis :

# %%
df[df['Ticket'] == 'CA. 2343']
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 159          160         0       3         Sage, Master. Thomas Henry    male
# 180          181         0       3       Sage, Miss. Constance Gladys  female
# 201          202         0       3                Sage, Mr. Frederick    male
# 324          325         0       3           Sage, Mr. George John Jr    male
# 792          793         0       3            Sage, Miss. Stella Anna  female
# 846          847         0       3           Sage, Mr. Douglas Bullen    male
# 863          864         0       3  Sage, Miss. Dorothy Edith "Dolly"  female
#
#      Age  SibSp  Parch    Ticket   Fare Cabin Embarked
# 159  NaN      8      2  CA. 2343  69.55   NaN        S
# 180  NaN      8      2  CA. 2343  69.55   NaN        S
# 201  NaN      8      2  CA. 2343  69.55   NaN        S
# 324  NaN      8      2  CA. 2343  69.55   NaN        S
# 792  NaN      8      2  CA. 2343  69.55   NaN        S
# ...

# %% [markdown]
# ## Conclusion :
# Here we can see , each member of the family is having same fare and same ticket number it means , tht if they were to be travelling with the family , all members had same ticket , and the fare given in this column is overall fare for the family , not an individual fare ,hence we are gonna calculate , the individual fare below

# %% [markdown]
# ## C) Creating new columns :
#
# ---
#
#
#
# ---

# %% [markdown]
# ## Finding individual fare for an individual passenger :

# %%
df['individual_fare'] = df['Fare']/(df['SibSp'] + df['Parch'] + 1)
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  individual_fare
# 0      0         A/5 21171   7.2500   NaN        S          3.62500
# 1      0          PC 17599  71.2833   C85        C         35.64165
# 2      0  STON/O2. 3101282   7.9250   NaN        S          7.92500
# ...

# %%
df['individual_fare'].plot(kind='box')
# Out:
# <Axes: >

# %%
df[['individual_fare','Fare']].describe()
# Out:
#        individual_fare        Fare
# count       891.000000  891.000000
# mean         19.916375   32.204208
# std          35.841257   49.693429
# min           0.000000    0.000000
# 25%           7.250000    7.910400
# 50%           8.300000   14.454200
# 75%          23.666667   31.000000
# max         512.329200  512.329200

# %%
df['Fare']
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %% [markdown]
# ## Creating new columns "Family_type"

# %%
df['family_size'] = df['SibSp'] + df['Parch'] + 1

# %%
# family_type
# 1 -> alone
# 2-4 -> small
# >5 -> large
def transform_family_size(num):

  if num == 1:
    return 'alone'
  elif num>1 and num <5:
    return "small"
  else:
    return "large"

# %%
df['family_type'] = df['family_size'].apply(transform_family_size)

# %%
pd.crosstab(df['Survived'],df['family_type'],normalize='columns')*100
# Out:
# family_type      alone      large      small
# Survived
# 0            69.646182  83.870968  42.123288
# 1            30.353818  16.129032  57.876712

# %% [markdown]
# ##Conclusion
#
# * Here we can conclude that ,passenger who were alone had 30% chance of survival.
# * Those with large families had 16 % chance of survival.
# * Those with small families had 57 % chance of survival.

# %% [markdown]
# ## Create new column surname

# %%
df['surname'] = df['Name'].str.split(',').str.get(0)
df['surname']
# Out:
# 0         Braund
# 1        Cumings
# 2      Heikkinen
# 3       Futrelle
# 4          Allen
#          ...
# 886     Montvila
# 887       Graham
# 888     Johnston
# 889         Behr
# 890       Dooley
# Name: surname, Length: 891, dtype: object

# %% [markdown]
# ## Creating new column "title"

# %%
df['title'] = df['Name'].str.split(',').str.get(1).str.strip().str.split(' ').str.get(0)
df['title']
# Out:
# 0        Mr.
# 1       Mrs.
# 2      Miss.
# 3       Mrs.
# 4        Mr.
#        ...
# 886     Rev.
# 887    Miss.
# 888    Miss.
# 889      Mr.
# 890      Mr.
# Name: title, Length: 891, dtype: object

# %%
temp_df = df[df['title'].isin(['Mr.','Miss.','Mrs.','Master.','ootherr'])]

# %%
pd.crosstab(temp_df['Survived'],temp_df['title'],normalize='columns')*100
# Out:
# title     Master.     Miss.        Mr.  Mrs.
# Survived
# 0            42.5  30.21978  84.332689  20.8
# 1            57.5  69.78022  15.667311  79.2

# %% [markdown]
# ##Conclusion
# * Here we can conclude that Those with title Master had 57.5 % chance of survival.
# * Similarly those with title Miss had 69 % chances of survival.
# * When it came to Mr and Mrs , Mrs had 79.2 % chance of survival which is much higher as compared to other titles.

# %%
df['title'] = df['title'].str.replace('Rev.','other')
df['title'] = df['title'].str.replace('Dr.','other')
df['title'] = df['title'].str.replace('Col.','other')
df['title'] = df['title'].str.replace('Major.','other')
df['title'] = df['title'].str.replace('Capt.','other')
df['title'] = df['title'].str.replace('the','other')
df['title'] = df['title'].str.replace('Jonkheer.','other')
# ,'Dr.','Col.','Major.','Don.','Capt.','the','Jonkheer.']
# Out:
# <ipython-input-99-ffb23deeff2c>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['title'] = df['title'].str.replace('Rev.','other')
# <ipython-input-99-ffb23deeff2c>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['title'] = df['title'].str.replace('Dr.','other')
# <ipython-input-99-ffb23deeff2c>:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['title'] = df['title'].str.replace('Col.','other')
# <ipython-input-99-ffb23deeff2c>:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['title'] = df['title'].str.replace('Major.','other')
# <ipython-input-99-ffb23deeff2c>:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['title'] = df['title'].str.replace('Capt.','other')
# ...

# %%
df['Cabin'].isnull().sum()/len(df['Cabin'])
# Out:
# 0.7710437710437711

# %%
df['Cabin'].fillna('M',inplace=True)

# %%
df['Cabin'].value_counts()
# Out:
# M              687
# C23 C25 C27      4
# G6               4
# B96 B98          4
# C22 C26          3
#               ...
# E34              1
# C7               1
# C54              1
# E36              1
# C148             1
# Name: Cabin, Length: 148, dtype: int64

# %% [markdown]
# ## Creating new column deck

# %%
df['deck'] = df['Cabin'].str[0]

# %%
df['deck'].value_counts()
# Out:
# C    59
# B    47
# D    33
# E    32
# A    15
# F    13
# G     4
# T     1
# Name: deck, dtype: int64

# %%
pd.crosstab(df['deck'],df['Pclass'])
# Out:
# Pclass   1    2    3
# deck
# A       15    0    0
# B       47    0    0
# C       59    0    0
# D       29    4    0
# E       25    4    3
# F        0    8    5
# G        0    0    4
# M       40  168  479
# T        1    0    0

# %%
pd.crosstab(df['deck'],df['Survived'],normalize='index').plot(kind='bar',stacked=True)
# Out:
# <Axes: xlabel='deck'>

# %% [markdown]
# ##Conclusion :
#
# *   Maximum passengers who survived the least were from
#     deck B ,D and E.
#
# *   Maximum people survived from deck M,A,and T

# %% [markdown]
# ## D) Mutivariate Analysis :
#
# ---
#
#
#
# ---

# %%
sns.heatmap(df.corr())
# Out:
# <ipython-input-103-aa4f4450a243>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %%
sns.pairplot(df)

# %% [markdown]
# #Overall conclusions :
#
# *   * Roughly 20 percent of the Age data is missing. The
#   proportion of Age missing is likely small enough for reasonable replacement with some form of imputation. Looking at the Cabin column, it looks like we are just missing too much of that data to do something useful with at a basic level.
#
# * - Age is normally(almost) distributed
#   - 20% of the values are missing
#   - There are some outliers
#
# * -   61.62 % of passengers died
#   -   38.38 % of passengers survived
#
# * -   64.76% are male passenger
#   -   35.24 % are female passenger
#
# * -   55.11 % passengers belong to class 3 , this indicates that fare for this class are much cheaper as compared to class 1 and 2
#  -   24.24 % passengers belong to class 1
#  -   20.65 % passengers belong to class 2
#  -  Fare price for class 1 and 2 are almost similar , due to which many passengers went for class 1 as compared to class 2
#
# * Survival percentage of people from different class :
#   - As we go from class 1 to class 3 people from higher class survived more as compared to people from lower class.
#   - Poor people , those who were in class 3 faced huge partiality , as compared to other class.
#
#   - Class 1 - 62.96 % Survived
#     Class 2 - 47.28 % Survived
#     Class 3 - 24.32 % Survived
#
#
# * - Female survival rate : 74.2  %
#   - Male survival rate   : 18.89 %
#
# *  Passengers who were from station
#    C , survived more , which indicates that , people from C station might of higher class and status.
#
#
# *  50 % of the passengers from
#     class 1 were from station c.
#
# * * For age 0-10/15 , 60-80 Survived
#   more , this means childrens and old aged peoples were given more priority for survival.
#
#   * For age 20-60 , most of the
#   people didnt survived.
#
#
# * *Passenger who were alone
#   had 30% chance of survival.
#   * Those with large families had 16 % chance of survival.
#   * Those with small families had 57 % chance of survival.
#
#
# * * Those with title Master
#     had 57.5 % chance of survival.
#   * Similarly those with title Miss had 69 % chances of survival.
#
#   * When it came to Mr and Mrs , Mrs had 79.2 % chance of survival which is much higher as compared to other titles.
#
# *
#   * Maximum passengers who survived the least were from
#     deck B ,D and E.
#
#   * Maximum people survived from deck M,A,and T

# %% [markdown]
# # Thankyou ⚛ 🔆
